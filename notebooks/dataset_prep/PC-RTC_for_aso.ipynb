# %% [markdown]
# # Download Sentinel-1 RTC for each ASO raster
# Given an ASO raster, find and download 1) the most proximate in time S1 RTC product 2) a "snow-off" RTC product from the preceeding summer.

# %%
# based on exmaples from
# https://planetarycomputer.microsoft.com/docs/tutorials/cloudless-mosaic-sentinel2/
# https://planetarycomputer.microsoft.com/dataset/sentinel-2-l2a#Example-Notebook
from pystac.extensions.eo import EOExtension as eo
import pystac_client
import planetary_computer
import glob
import rioxarray as rxr
import re
import datetime
import pandas as pd
from shapely.geometry import box
import odc.stac
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import rasterio as rio
import traceback

# %%
def rtc_for_aso_snowon(aso_raster_fn):
    time = pd.to_datetime(re.search("(\d{4}\d{2}\d{2})", aso_raster_fn).group())
    week_before = (time - datetime.timedelta(weeks=2)).strftime('%Y-%m-%d')
    week_after = (time + datetime.timedelta(weeks=2)).strftime('%Y-%m-%d')
    time_of_interest = f'{week_before}/{week_after}'
    
    aso_raster = rxr.open_rasterio(aso_raster_fn).squeeze()
    aso_raster = aso_raster.where(aso_raster>=0, drop=True)
    bounds_latlon = box(*aso_raster.rio.transform_bounds("EPSG:4326"))
    
    catalog = pystac_client.Client.open(
    "https://planetarycomputer.microsoft.com/api/stac/v1",
    modifier=planetary_computer.sign_inplace)

    search = catalog.search(
        collections=["sentinel-1-rtc"],
        intersects=bounds_latlon,
        datetime=time_of_interest)
    
    # Check how many items were returned
    items = search.item_collection()
    
    rtc_stac = odc.stac.load(items,chunks={"x": 2048, "y": 2048},resolution=50, groupby='sat:absolute_orbit')
    print(f"Returned {len(rtc_stac.time)} acquisitions")
    rtc_stac_clipped = rtc_stac.rio.clip_box(*bounds_latlon.bounds,crs="EPSG:4326")
    
    rel_orbits = [scene.properties['sat:relative_orbit'] for scene in items.items]
    ac_times = [scene.properties['datetime'] for scene in items.items]
    ac_times = [np.datetime64(item) for item in ac_times]
    
    # clip to ASO extent
    rtc_stac_clipped = rtc_stac_clipped.rio.reproject_match(aso_raster, resampling=rio.enums.Resampling.bilinear)

    # limit to morning acquisitions
    rtc_ds = rtc_stac_clipped.where(rtc_stac_clipped.time.dt.hour > 11, drop=True)
    if 'vv' not in list(rtc_ds.keys()) or 'vh' not in list(rtc_ds.keys()):
        print('missing polarization')
        return None
    
    if len(rtc_ds.time) == 0:
        print('no morning acquisitions')
        return None
        
    # calculate percent vh coverage of each acquisition
    perc_cover = (rtc_ds.vh.where(aso_raster >= 0) > 0).sum(dim=['x', 'y'])/(rtc_ds.vh.where(aso_raster >= 0) >= -1000000000).sum(dim=['x', 'y'])
    
    # if multiple with full coverage, grab nearest in time with full coverage
    if perc_cover.values.tolist().count(1) > 1:
        print('total snow-on coverage available')
        rtc_ds = rtc_ds.where(perc_cover == 1, drop=True).sortby('time')
        rtc_ds = rtc_ds.sel(time=time, method='nearest')

    # exit if no rasters have good vh coverage
    elif perc_cover.max() < 0.01:
        print('max vh coverage is < 1%--recommend skipping ASO raster')
        return None

    # otherwise, grab max coverage 
    else:
        if perc_cover.max() == 1:
            print('total snow-on coverage available')
        else: 
            print(f'{perc_cover.max().item()} snow-on coverage')
        rtc_ds = rtc_ds.sel(time=perc_cover.idxmax())

    # get relative orbit of scene
    rel_orbit = rel_orbits[ac_times.index(rtc_ds.time)]
    
    # mask negative areas
    rtc_ds = rtc_ds.where(rtc_ds.vh > 0)
    rtc_ds = rtc_ds.where(rtc_ds.vv > 0)
    
    rtc_ds.to_netcdf(rf"C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\S1_rtc\S1_snow-on_{rtc_ds.time.dt.strftime("%Y%m%d").item()}_for_{aso_raster_fn.split("\\")[-1][:-4]}.nc")
    
    return rel_orbit

# %%
def rtc_for_aso_snowoff(aso_raster_fn, rel_orbit):
    year = pd.to_datetime(re.search("(\d{4}\d{2}\d{2})", aso_raster_fn).group()).year
    time = pd.to_datetime(f'{year-1}0910')
    week_before = (time - datetime.timedelta(weeks=2)).strftime('%Y-%m-%d')
    week_after = (time + datetime.timedelta(weeks=2)).strftime('%Y-%m-%d')
    time_of_interest = f'{week_before}/{week_after}'

    aso_raster = rxr.open_rasterio(aso_raster_fn).squeeze()
    aso_raster = aso_raster.where(aso_raster>=0, drop=True)
    bounds_latlon = box(*aso_raster.rio.transform_bounds("EPSG:4326"))

    catalog = pystac_client.Client.open(
    "https://planetarycomputer.microsoft.com/api/stac/v1",
    modifier=planetary_computer.sign_inplace)

    search = catalog.search(
        collections=["sentinel-1-rtc"],
        intersects=bounds_latlon,
        datetime=time_of_interest)

    # Check how many items were returned
    items = search.item_collection()

    rel_orbits = [scene.properties['sat:relative_orbit'] for scene in items.items]
    ac_times = [scene.properties['datetime'] for scene in items.items]
    ac_times = [np.datetime64(item) for item in ac_times]

    rtc_stac = odc.stac.load(items,chunks={"x": 2048, "y": 2048},resolution=50, groupby='sat:absolute_orbit')
    print(f"Returned {len(rtc_stac.time)} acquisitions")
    rtc_stac_clipped = rtc_stac.rio.clip_box(*bounds_latlon.bounds,crs="EPSG:4326")

    orbit_dict = {}
    for i, orbit in enumerate(rel_orbits):
        if orbit not in orbit_dict.keys():
            orbit_dict[orbit] = [ac_times[i]]
        else:
            orbit_dict[orbit].append(ac_times[i])

    if rel_orbit not in orbit_dict.keys():
        print('no acquisitons from same orbit, skipping')
        return

    rtc_stac_clipped = rtc_stac_clipped.where(rtc_stac_clipped.time.isin(orbit_dict[rel_orbit]), drop=True)

    # clip to ASO extent
    rtc_stac_clipped = rtc_stac_clipped.rio.reproject_match(aso_raster, resampling=rio.enums.Resampling.bilinear)

    # limit to morning acquisitions
    rtc_ds = rtc_stac_clipped.where(rtc_stac_clipped.time.dt.hour > 11, drop=True)
    if 'vv' not in list(rtc_ds.keys()) or 'vh' not in list(rtc_ds.keys()):
            print('missing polarization, skipping')
            return
    
    if len(rtc_ds.time) == 0:
        print('no morning acquisitions')
        return None

    # calculate percent vh coverage of each acquisition
    perc_cover = (rtc_ds.vh.where(aso_raster >= 0) > 0).sum(dim=['x', 'y'])/(rtc_ds.vh.where(aso_raster >= 0) >= -1000000000).sum(dim=['x', 'y'])

    # if multiple with full coverage, grab nearest in time with full coverage
    if perc_cover.values.tolist().count(1) > 1:
        print('total snow-off coverage available')
        rtc_ds = rtc_ds.where(perc_cover == 1, drop=True).sortby('time')
        rtc_ds = rtc_ds.sel(time=time, method='nearest')

    # exit if no rasters have good vh coverage
    elif perc_cover.max() < 0.01:
        print('max vh coverage is < 1%--recommend skipping ASO raster')
        return

    # otherwise, grab max coverage 
    else:
        if perc_cover.max() == 1:
            print('total snow-off coverage available')
        else: 
            print(f'{perc_cover.max().item()} snow-off coverage')
        rtc_ds = rtc_ds.sel(time=perc_cover.idxmax())
    
    # mask negative areas
    rtc_ds = rtc_ds.where(rtc_ds.vh > 0)
    rtc_ds = rtc_ds.where(rtc_ds.vv > 0)
    
    rtc_ds.to_netcdf(rf"C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\S1_rtc\S1_snow-off_{rtc_ds.time.dt.strftime("%Y%m%d").item()}_for_{aso_raster_fn.split("\\")[-1][:-4]}.nc")

# %%
def rtc_for_aso_all(dir_path):
    raster_paths = glob.glob(rf'{dir_path}\utm11n\ASO_50M_SD*.tif')
    for i, path in enumerate(raster_paths):
        print(f'----\nworking on {path.split("/")[-1]}, {i+1}/{len(raster_paths)}\n----')
        
        try:
            relative_orbit = rtc_for_aso_snowon(path)
            if relative_orbit == None:
                continue
            rtc_for_aso_snowoff(path, relative_orbit)
        except Exception as exc:
            print(traceback.format_exc())
            print(exc)
            print('encountered error, skipping')

# %%
dir_path = r"C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned"
test = rtc_for_aso_all(dir_path)
# Out:
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Carson_20220311_clean.tif, 1/159
# ----
# Returned 7 acquisitions
# total snow-on coverage available
# Returned 19 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Carson_20220406_clean.tif, 2/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 19 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Carson_20220513_clean.tif, 3/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 19 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Carson_20230331_clean.tif, 4/159
# ----
# Returned 9 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Carson_20230510_clean.tif, 5/159
# ----
# Returned 9 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Carson_20230607_clean.tif, 6/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kaweah_20210423_clean.tif, 7/159
# ----
# Returned 18 acquisitions
# total snow-on coverage available
# Returned 18 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kaweah_20210504_clean.tif, 8/159
# ----
# Returned 18 acquisitions
# total snow-on coverage available
# Returned 18 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kaweah_20220308_clean.tif, 9/159
# ----
# Returned 9 acquisitions
# total snow-on coverage available
# Returned 20 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kaweah_20220327_clean.tif, 10/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 20 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kaweah_20220429_clean.tif, 11/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 20 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kaweah_20220517_clean.tif, 12/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 20 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kaweah_20230127_clean.tif, 13/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kaweah_20230307_clean.tif, 14/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kaweah_20230405_clean.tif, 15/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kaweah_20230423_clean.tif, 16/159
# ----
# Returned 8 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kaweah_20230602_clean.tif, 17/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kern_20230204_clean.tif, 18/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kern_20230326_clean.tif, 19/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kern_20230429_clean.tif, 20/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kern_20230603_clean.tif, 21/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kings_20230122_clean.tif, 22/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kings_20230316_clean.tif, 23/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kings_20230331_clean.tif, 24/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kings_20230421_clean.tif, 25/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kings_20230528_clean.tif, 26/159
# ----
# Returned 8 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kings_20230630_clean.tif, 27/159
# ----
# Returned 9 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20200413_clean.tif, 28/159
# ----
# Returned 16 acquisitions
# total snow-on coverage available
# Returned 15 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20200507_clean.tif, 29/159
# ----
# Returned 18 acquisitions
# total snow-on coverage available
# Returned 15 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20200521_clean.tif, 30/159
# ----
# Returned 20 acquisitions
# total snow-on coverage available
# Returned 15 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20200604_clean.tif, 31/159
# ----
# Returned 20 acquisitions
# total snow-on coverage available
# Returned 15 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20210429_clean.tif, 32/159
# ----
# Returned 18 acquisitions
# total snow-on coverage available
# Returned 18 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20210526_clean.tif, 33/159
# ----
# Returned 18 acquisitions
# total snow-on coverage available
# Returned 18 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20220301_clean.tif, 34/159
# ----
# Returned 8 acquisitions
# total snow-on coverage available
# Returned 19 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20220412_clean.tif, 35/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 19 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20220428_clean.tif, 36/159
# ----
# Returned 9 acquisitions
# total snow-on coverage available
# Returned 19 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20220513_clean.tif, 37/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 19 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20230131_clean.tif, 38/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20230303_clean.tif, 39/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20230326_clean.tif, 40/159
# ----
# Returned 9 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20230515_clean.tif, 41/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20230608_clean.tif, 42/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Mono_20230527_clean.tif, 43/159
# ----
# Returned 8 acquisitions
# total snow-on coverage available
# Returned 7 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Mono_20230615_clean.tif, 44/159
# ----
# Returned 7 acquisitions
# total snow-on coverage available
# Returned 7 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Mono_20230702_clean.tif, 45/159
# ----
# Returned 7 acquisitions
# total snow-on coverage available
# Returned 7 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_SanJoaquin_20200523_clean.tif, 46/159
# ----
# Returned 20 acquisitions
# total snow-on coverage available
# Returned 15 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_SanJoaquin_20200608_clean.tif, 47/159
# ----
# Returned 20 acquisitions
# total snow-on coverage available
# Returned 15 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_SanJoaquin_20210226_clean.tif, 48/159
# ----
# Returned 19 acquisitions
# total snow-on coverage available
# Returned 18 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_SanJoaquin_20210331_clean.tif, 49/159
# ----
# Returned 20 acquisitions
# total snow-on coverage available
# Returned 18 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_SanJoaquin_20210503_clean.tif, 50/159
# ----
# Returned 17 acquisitions
# total snow-on coverage available
# Returned 18 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_SanJoaquin_20220206_clean.tif, 51/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 19 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_SanJoaquin_20220316_clean.tif, 52/159
# ----
# Returned 8 acquisitions
# total snow-on coverage available
# Returned 19 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_SanJoaquin_20220417_clean.tif, 53/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 19 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_SanJoaquin_20220430_clean.tif, 54/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 19 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_SanJoaquin_20230121_clean.tif, 55/159
# ----
# Returned 9 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_SanJoaquin_20230317_clean.tif, 56/159
# ----
# Returned 7 acquisitions
# total snow-on coverage available
# Returned 9 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_SanJoaquin_20230414_clean.tif, 57/159
# ----
# Returned 7 acquisitions
# total snow-on coverage available
# Returned 7 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_SanJoaquin_20230523_clean.tif, 58/159
# ----
# Returned 8 acquisitions
# total snow-on coverage available
# Returned 7 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_SanJoaquin_20230623_clean.tif, 59/159
# ----
# Returned 8 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Tuolumne_20200413_clean.tif, 60/159
# ----
# Returned 16 acquisitions
# total snow-on coverage available
# Returned 15 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Tuolumne_20200507_clean.tif, 61/159
# ----
# Returned 18 acquisitions
# total snow-on coverage available
# Returned 15 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Tuolumne_20210224_clean.tif, 62/159
# ----
# Returned 19 acquisitions
# total snow-on coverage available
# Returned 18 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Tuolumne_20210429_clean.tif, 63/159
# ----
# Returned 18 acquisitions
# total snow-on coverage available
# Returned 18 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Tuolumne_20220204_clean.tif, 64/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 19 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Tuolumne_20220228_clean.tif, 65/159
# ----
# Returned 8 acquisitions
# total snow-on coverage available
# Returned 19 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Tuolumne_20220405_clean.tif, 66/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 19 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Tuolumne_20220429_clean.tif, 67/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 19 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Tuolumne_20220518_clean.tif, 68/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 19 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Tuolumne_20230124_clean.tif, 69/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Tuolumne_20230302_clean.tif, 70/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Tuolumne_20230316_clean.tif, 71/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Tuolumne_20230427_clean.tif, 72/159
# ----
# Returned 9 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Tuolumne_20230601_clean.tif, 73/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Tuolumne_20230626_clean.tif, 74/159
# ----
# Returned 7 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_UpperOwensBasin_20230527_clean.tif, 75/159
# ----
# Returned 8 acquisitions
# total snow-on coverage available
# Returned 7 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_UpperOwensBasin_20230615_clean.tif, 76/159
# ----
# Returned 7 acquisitions
# total snow-on coverage available
# Returned 7 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_UpperOwensBasin_20230702_clean.tif, 77/159
# ----
# Returned 7 acquisitions
# total snow-on coverage available
# Returned 7 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCAJW_20180423_clean.tif, 78/159
# ----
# Returned 9 acquisitions
# total snow-on coverage available
# Returned 8 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCAJW_20180602_clean.tif, 79/159
# ----
# Returned 11 acquisitions
# total snow-on coverage available
# Returned 11 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCAJW_20190315_clean.tif, 80/159
# ----
# Returned 16 acquisitions
# total snow-on coverage available
# Returned 12 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCAJW_20190605_clean.tif, 81/159
# ----
# Returned 14 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCAKC_20180426_clean.tif, 82/159
# ----
# Returned 8 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCAKC_20190316_clean.tif, 83/159
# ----
# Returned 15 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCAKC_20190326_clean.tif, 84/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 8 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCAKC_20190418_clean.tif, 85/159
# ----
# Returned 14 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCAKC_20190427_clean.tif, 86/159
# ----
# Returned 14 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCAKC_20190428_clean.tif, 87/159
# ----
# Returned 14 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCAKC_20190608_clean.tif, 88/159
# ----
# Returned 14 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCAKC_20190611_clean.tif, 89/159
# ----
# Returned 11 acquisitions
# total snow-on coverage available
# Returned 8 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCAKN_20180426_clean.tif, 90/159
# ----
# Returned 5 acquisitions
# total snow-on coverage available
# Returned 7 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCAKN_20190417_clean.tif, 91/159
# ----
# Returned 12 acquisitions
# total snow-on coverage available
# Returned 8 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCAKW_20190317_clean.tif, 92/159
# ----
# Returned 15 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCAKW_20190324_clean.tif, 93/159
# ----
# Returned 14 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCAKW_20190421_clean.tif, 94/159
# ----
# Returned 14 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCALB_20160509_clean.tif, 95/159
# ----
# Returned 6 acquisitions
# total snow-on coverage available
# Returned 3 acquisitions
# missing polarization, skipping
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCALB_20160607_clean.tif, 96/159
# ----
# Returned 5 acquisitions
# total snow-on coverage available
# Returned 3 acquisitions
# missing polarization, skipping
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCALB_20160614_clean.tif, 97/159
# ----
# Returned 3 acquisitions
# max vh coverage is < 1%--recommend skipping ASO raster
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCALB_20160621_clean.tif, 98/159
# ----
# Returned 3 acquisitions
# max vh coverage is < 1%--recommend skipping ASO raster
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCALB_20160626_clean.tif, 99/159
# ----
# Returned 4 acquisitions
# max vh coverage is < 1%--recommend skipping ASO raster
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCALB_20170128_clean.tif, 100/159
# ----
# Returned 13 acquisitions
# total snow-on coverage available
# Returned 6 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCALB_20170815_clean.tif, 101/159
# ----
# Returned 7 acquisitions
# total snow-on coverage available
# Returned 6 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCALB_20180422_clean.tif, 102/159
# ----
# Returned 7 acquisitions
# total snow-on coverage available
# Returned 7 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCALB_20180601_clean.tif, 103/159
# ----
# Returned 6 acquisitions
# total snow-on coverage available
# Returned 7 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCALB_20190309_clean.tif, 104/159
# ----
# Returned 11 acquisitions
# total snow-on coverage available
# Returned 8 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCALB_20190501_clean.tif, 105/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 8 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCALB_20190611_clean.tif, 106/159
# ----
# Returned 11 acquisitions
# total snow-on coverage available
# Returned 8 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCALB_20190703_clean.tif, 107/159
# ----
# Returned 12 acquisitions
# total snow-on coverage available
# Returned 8 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCALB_20190715_clean.tif, 108/159
# ----
# Returned 12 acquisitions
# total snow-on coverage available
# Returned 8 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCALV_20170717_clean.tif, 109/159
# ----
# Returned 6 acquisitions
# total snow-on coverage available
# Returned 5 acquisitions
# max vh coverage is < 1%--recommend skipping ASO raster
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCAMB_20180425_clean.tif, 110/159
# ----
# Returned 8 acquisitions
# total snow-on coverage available
# Returned 8 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCAMB_20190329_clean.tif, 111/159
# ----
# Returned 14 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCAMB_20190604_clean.tif, 112/159
# ----
# Returned 14 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCAMB_20190703_clean.tif, 113/159
# ----
# Returned 15 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCAMB_20190716_clean.tif, 114/159
# ----
# Returned 15 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCARC_20160412_clean.tif, 115/159
# ----
# Returned 5 acquisitions
# 0.506080776737901 snow-on coverage
# Returned 3 acquisitions
# missing polarization, skipping
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCARC_20170717_clean.tif, 116/159
# ----
# Returned 6 acquisitions
# total snow-on coverage available
# Returned 6 acquisitions
# 0.5224608681238012 snow-off coverage
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCASF_20170718_clean.tif, 117/159
# ----
# Returned 7 acquisitions
# total snow-on coverage available
# Returned 6 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCASF_20180423_clean.tif, 118/159
# ----
# Returned 7 acquisitions
# total snow-on coverage available
# Returned 7 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCASF_20180601_clean.tif, 119/159
# ----
# Returned 6 acquisitions
# total snow-on coverage available
# Returned 7 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCASF_20190317_clean.tif, 120/159
# ----
# Returned 12 acquisitions
# total snow-on coverage available
# Returned 8 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCASF_20190502_clean.tif, 121/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 8 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCASF_20190609_clean.tif, 122/159
# ----
# Returned 11 acquisitions
# total snow-on coverage available
# Returned 8 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCASF_20190704_clean.tif, 123/159
# ----
# Returned 12 acquisitions
# total snow-on coverage available
# Returned 8 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCASF_20190714_clean.tif, 124/159
# ----
# Returned 12 acquisitions
# total snow-on coverage available
# Returned 8 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCASJ_20170129_clean.tif, 125/159
# ----
# Returned 17 acquisitions
# total snow-on coverage available
# Returned 9 acquisitions
# 0.999154092729129 snow-off coverage
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCASJ_20170719_clean.tif, 126/159
# ----
# Returned 7 acquisitions
# total snow-on coverage available
# Returned 6 acquisitions
# 0.9670375251520893 snow-off coverage
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCASJ_20170815_clean.tif, 127/159
# ----
# Returned 7 acquisitions
# total snow-on coverage available
# Returned 6 acquisitions
# 0.9920709958087025 snow-off coverage
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCASJ_20180304_clean.tif, 128/159
# ----
# Returned 8 acquisitions
# total snow-on coverage available
# Returned 7 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCASJ_20180422_clean.tif, 129/159
# ----
# Returned 7 acquisitions
# total snow-on coverage available
# Returned 7 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCASJ_20180601_clean.tif, 130/159
# ----
# Returned 6 acquisitions
# total snow-on coverage available
# Returned 7 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCASJ_20190325_clean.tif, 131/159
# ----
# Returned 12 acquisitions
# total snow-on coverage available
# Returned 8 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCASJ_20190501_clean.tif, 132/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 8 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCASJ_20190614_clean.tif, 133/159
# ----
# Returned 12 acquisitions
# total snow-on coverage available
# Returned 8 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCASJ_20190704_clean.tif, 134/159
# ----
# Returned 12 acquisitions
# total snow-on coverage available
# Returned 8 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCASJ_20190713_clean.tif, 135/159
# ----
# Returned 11 acquisitions
# total snow-on coverage available
# Returned 8 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCATB_20160326_clean.tif, 136/159
# ----
# Returned 8 acquisitions
# 0.01575632853059237 snow-on coverage
# Returned 4 acquisitions
# missing polarization, skipping
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCATB_20160401_clean.tif, 137/159
# ----
# Returned 7 acquisitions
# 0.016293259500864025 snow-on coverage
# Returned 4 acquisitions
# missing polarization, skipping
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCATB_20160407_clean.tif, 138/159
# ----
# Returned 8 acquisitions
# 0.011877729763545999 snow-on coverage
# Returned 4 acquisitions
# missing polarization, skipping
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCATB_20160416_clean.tif, 139/159
# ----
# Returned 7 acquisitions
# 0.49413143327034276 snow-on coverage
# Returned 4 acquisitions
# missing polarization, skipping
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCATB_20160426_clean.tif, 140/159
# ----
# Returned 8 acquisitions
# 0.4939272428479717 snow-on coverage
# Returned 4 acquisitions
# missing polarization, skipping
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCATB_20160509_clean.tif, 141/159
# ----
# Returned 8 acquisitions
# 0.012482530342037513 snow-on coverage
# Returned 4 acquisitions
# missing polarization, skipping
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCATB_20160527_clean.tif, 142/159
# ----
# Returned 9 acquisitions
# 0.016563097418950578 snow-on coverage
# Returned 4 acquisitions
# missing polarization, skipping
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCATB_20160607_clean.tif, 143/159
# ----
# Returned 7 acquisitions
# 0.016788526434195726 snow-on coverage
# Returned 4 acquisitions
# missing polarization, skipping
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCATB_20160708_clean.tif, 144/159
# ----
# Returned 4 acquisitions
# max vh coverage is < 1%--recommend skipping ASO raster
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCATB_20170717_clean.tif, 145/159
# ----
# Returned 8 acquisitions
# total snow-on coverage available
# Returned 8 acquisitions
# 0.01831201063397978 snow-off coverage
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCATB_20170727_clean.tif, 146/159
# ----
# Returned 8 acquisitions
# total snow-on coverage available
# Returned 8 acquisitions
# 0.01845713283120073 snow-off coverage
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCATB_20170816_clean.tif, 147/159
# ----
# Returned 9 acquisitions
# total snow-on coverage available
# Returned 8 acquisitions
# 0.018116302986737703 snow-off coverage
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCATB_20180423_clean.tif, 148/159
# ----
# Returned 9 acquisitions
# total snow-on coverage available
# Returned 8 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCATB_20180528_clean.tif, 149/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 8 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCATE_20190324_clean.tif, 150/159
# ----
# Returned 14 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCATE_20190417_clean.tif, 151/159
# ----
# Returned 14 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCATE_20190503_clean.tif, 152/159
# ----
# Returned 14 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCATE_20190613_clean.tif, 153/159
# ----
# Returned 13 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USCATE_20190705_clean.tif, 154/159
# ----
# Returned 14 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USIDBS_20200218_clean.tif, 155/159
# ----
# Returned 12 acquisitions
# total snow-on coverage available
# Returned 5 acquisitions
# no acquisitons from same orbit, skipping
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USIDBS_20210315_clean.tif, 156/159
# ----
# Returned 12 acquisitions
# total snow-on coverage available
# Returned 13 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USIDDC_20200219_clean.tif, 157/159
# ----
# Returned 14 acquisitions
# total snow-on coverage available
# Returned 9 acquisitions
# total snow-off coverage available
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USIDMC_20200209_clean.tif, 158/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 5 acquisitions
# 0.40551039493561614 snow-off coverage
# ----
# working on C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_USIDMC_20210315_clean.tif, 159/159
# ----
# Returned 10 acquisitions
# total snow-on coverage available
# Returned 10 acquisitions
# total snow-off coverage available
