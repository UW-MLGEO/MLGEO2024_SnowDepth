# %% [markdown]
# # Organizing Data into AI-Ready Format
# Task: Prepare the cleaned data for machine learning, ensuring it is properly annotated and structured.
# - Convert your data into a format suitable for ML (e.g., pandas DataFrame, NumPy arrays, Xarray).
#
# - Ensure the data is well-documented with attributes, labels, and metadata.
#
# - Include a notebook (notebooks/Prepare_AI_Ready_Data.ipynb) that clearly describes:
#
# - The final shape of the data (number of samples, features, and target labels).
#
# - A description of each feature/attribute.
#
# - Save the final AI-ready data in a dedicated folder (data/ai_ready/).

# %%
# When preparing our data to be 'AI-ready', our main focus is spatially aligning all of our datasets and making sure
# they're of the same shape (and handling missing values)

# below is the same writeup for data cleaning since they two sections are intertwined for us

# you'll see in every one of the downloaded data that we load here, we squeeze the data, rename columns to short yet explanatory names
# with no special characters, and ensure spatial overlap by projecting to the same CRS

# a big part of this preprocessing since we're working with data of differing spatial resolution is the rio.enums.Resampling.bilinear method.
# as you know, our target data is in 50x50m spatial resolution which is what we're re-fitting other data sources to. This method allows data
# of larger spatial resolution to "shrink" so the 50x50m output cells take on whatever value of the bigger cell they're within. This calue
# is averaged between multiple cells if the topology is not perfect. This same averaging principle is in place when mapping finer spatial resolutions to 50x50cm

# for the main loop, you'll see that we iterate over tiles. by using the "Create grid" tool in QGIS, we are able to create 32x32km grids (1024 km**2)
# over the ASO LiDAR flights. For each grid, we subdivide all data within into 128x128 rasters of 50x50m spatial resolution (a little larger than 40 km**2).
# All subvised tiles are kept as long as they contain some raster data. It should be noted that the ASO LiDAR data are clipped to a water basin
# which might alarm some users that a lot of NaN values will exhibited by subtiles around the edges, but this is actually not the case after some 
# manual inspection. All subtiles have a significant-enough amount of data

# for handling missing values, you'll see that we have "gap maps" or various features where there are gaps in the 'ground truth' snow depth,
# sentinel-1 backscatter, and sentinel-2 multispectral data. The FCF data and elevation data do not have missing values so they didn't need to be handled
# we can treet these maps as masks when processing the data and ml model

# %%
from glob import glob
import numpy as np
import xarray as xr
import rasterio as rio
import rioxarray as rxr
import geopandas as gpd
import random
import matplotlib.pyplot as plt
from rioxarray import merge
import gc
from pyproj import Proj, transform
import math
import xdem

import warnings
warnings.filterwarnings("ignore")

# %%
def open_all_data(aso_path, home_path):
    aso_fn = aso_path.split('\\')[-1][:-4]
    S1_snowon_path = glob(rf'{home_path}\S1_rtc\S1_snow-on_*_for_{aso_fn}.nc')[0]
    S1_snowoff_path = glob(rf'{home_path}\S1_rtc\S1_snow-off_*_for_{aso_fn}.nc')[0]
    S1_snowon_mean_path = glob(rf'{home_path}\S1_rtc_mean\S1_snow-on_*_for_{aso_fn}.nc')[0]
    S1_snowoff_mean_path = glob(rf'{home_path}\S1_rtc_mean\S1_snow-off_*_for_{aso_fn}.nc')[0]
    # i messed up the file naming for sentinel 2 when i preprocessed the data, so i have to do this
    S2_path = glob(rf'{home_path}\sentinel_2\{aso_path.split('\\')[-1].split('_')[-2]}_for_{aso_fn}.nc')[0]
    fcf_path = glob(rf'{home_path}\fcf\fcf_for_{aso_fn}.nc')[0]
    dem_path = glob(rf'{home_path}\cop30\cop30_for_{aso_fn}.nc')[0]
    
    aso_ds = xr.open_dataset(aso_path).squeeze()
    aso_ds = aso_ds.rename({'band_data': 'aso_sd'})
    aso_ds['aso_sd'] = aso_ds['aso_sd'].where(aso_ds['aso_sd'] >= 0)
    
    S1_snowon_ds = xr.open_dataset(S1_snowon_path).squeeze()
    S1_snowon_ds = S1_snowon_ds.rename({'vv': 'snowon_vv', 'vh':'snowon_vh'})
    S1_snowon_ds = S1_snowon_ds.rio.reproject_match(aso_ds, resampling=rio.enums.Resampling.bilinear, crs=aso_ds.rio.crs)
    S1_snowoff_ds = xr.open_dataset(S1_snowoff_path).squeeze()
    S1_snowoff_ds = S1_snowoff_ds.rename({'vv': 'snowoff_vv', 'vh':'snowoff_vh'})
    S1_snowoff_ds = S1_snowoff_ds.rio.reproject_match(aso_ds, resampling=rio.enums.Resampling.bilinear, crs=aso_ds.rio.crs)
    
    S1_snowon_mean_ds = xr.open_dataset(S1_snowon_mean_path).squeeze()
    S1_snowon_mean_ds = S1_snowon_mean_ds.rename({'vv': 'snowon_vv_mean', 'vh':'snowon_vh_mean'})
    S1_snowon_mean_ds = S1_snowon_mean_ds.rio.reproject_match(aso_ds, resampling=rio.enums.Resampling.bilinear, crs=aso_ds.rio.crs)
    S1_snowoff_mean_ds = xr.open_dataset(S1_snowoff_mean_path).squeeze()
    S1_snowoff_mean_ds = S1_snowoff_mean_ds.rename({'vv': 'snowoff_vv_mean', 'vh':'snowoff_vh_mean'})
    S1_snowoff_mean_ds = S1_snowoff_mean_ds.rio.reproject_match(aso_ds, resampling=rio.enums.Resampling.bilinear, crs=aso_ds.rio.crs)
    
    S2_ds = xr.open_dataset(S2_path).squeeze()
    S2_ds = S2_ds.rio.write_crs(aso_ds.rio.crs)
    S2_ds = S2_ds.rio.reproject_match(aso_ds, resampling=rio.enums.Resampling.bilinear, crs=aso_ds.rio.crs) 
    
    fcf_ds = xr.open_dataset(fcf_path).squeeze()
    fcf_ds = fcf_ds.rename({'__xarray_dataarray_variable__': 'fcf'})
    fcf_ds = fcf_ds.rio.reproject_match(aso_ds, resampling=rio.enums.Resampling.bilinear, crs=aso_ds.rio.crs)
    
    dem_ds = xr.open_dataset(dem_path).squeeze()
    dem_ds = dem_ds.rio.write_crs(aso_ds.rio.crs)
    dem_ds = dem_ds.rename({'__xarray_dataarray_variable__': 'elevation'})
    dem_ds = dem_ds.rio.reproject_match(aso_ds, resampling=rio.enums.Resampling.bilinear, crs=aso_ds.rio.crs)
    
    ds_list = [aso_ds, S1_snowon_ds, S1_snowoff_ds, S2_ds, fcf_ds, dem_ds]
    
    ds = xr.merge(ds_list, compat='override', join='override').squeeze()

    # add terrain variables
    transform = (50, 0.0, ds.isel(x=0, y=0).x.item(), 0.0, 50, ds.isel(x=0, y=0).y.item())
    dem = xdem.DEM.from_array(ds.elevation.values, transform, crs=ds.rio.crs)
    ds['aspect'] = (('y', 'x'), xdem.terrain.aspect(dem).data.data)
    ds['slope'] = (('y', 'x'), xdem.terrain.slope(dem).data.data)
    ds['curvature'] = (('y', 'x'), xdem.terrain.curvature(dem).data.data)
    ds['tpi'] = (('y', 'x'), xdem.terrain.topographic_position_index(dem).data.data)
    ds['tri'] = (('y', 'x'), xdem.terrain.terrain_ruggedness_index(dem).data.data)

    return aso_fn, ds

# %%
subset_size = 128

home_path = r"C:\Users\JackE\uw\courses\aut24\ml_geo\final_data"
utm_zones = ['utm10n', 'utm11n', 'utm12n', 'utm13n']
total_subsets = 0

# loop through utm zones
for i, utm_zone in enumerate(utm_zones):
    print(f'working on {utm_zone} file {i}')
    aso_paths = glob(rf'{home_path}\ASO_50m_SD_cleaned\{utm_zone}\*')
    tile_names = [f'train_{utm_zone}_32km.shp', f'test_{utm_zone}_32km.shp', f'val_{utm_zone}_32km.shp']

    # define projections for lat and lon data variables
    utm_proj = Proj(proj='utm', zone=utm_zone[3:-1], ellps='WGS84')
    wgs84_proj = Proj(proj='latlong', datum='WGS84')

    #loop through train, val, test tiles
    for tile_set in tile_names:
        # open tiles 
        print(f'working on {tile_set}')
        tiles = gpd.read_file(rf'{home_path}\tiles\{tile_set}')

        #loop through ASO rasters
        for aso_path in aso_paths:
            # open aso raster
            raster_subsets = 0
            try:
                print(aso_path, home_path)
                aso_fn, ds = open_all_data(aso_path, home_path)
            except Exception as e:
                print(f'encountered error opening dataset {aso_fn}... missing S2 data, skipping')
                aso_fn = aso_path.split('\\')[-1][:-4]
                print(rf'no {home_path}\sentinel_2\{aso_path.split('\\')[-1].split('_')[-2]}_for_{aso_fn}.nc')
                continue
            print(f'working on {aso_fn}')

            # loop through tiles
            for tile in tiles.iterrows():
                # clip to tile extent
                try:
                    tile_ds = ds.rio.clip([tile[1].geometry], crs=ds.rio.crs, drop=True)
                except: #except if tile does not overlap aso raster
                    continue

                # pad ds to tile extent
                tile_ds = tile_ds.rio.pad_box(miny=tile[1].geometry.bounds[1],
                                              minx=tile[1].geometry.bounds[0],
                                              maxy=tile[1].geometry.bounds[3],
                                              maxx=tile[1].geometry.bounds[2])

                subset_count = 0
                #loop through subset locations
                for i in range(round((len(tile_ds.x)/subset_size))):
                    for j in range(round((len(tile_ds.y)/subset_size))):
                        ymin = j*subset_size
                        ymax = ymin+subset_size
                        xmin = i*subset_size
                        xmax = xmin+subset_size
            
                        subset_ds = tile_ds.isel(x=slice(xmin, xmax), y=slice(ymin, ymax))
            
                        valid_aso = np.invert(np.isnan(subset_ds.aso_sd))
                        
                        # check if subset has valid ASO pixels
                        if valid_aso.sum() == 0:
                            continue

                        # make sure dimensions are correct
                        if len(subset_ds.x) != subset_size or len(subset_ds.y) != subset_size:
                            continue
                    
                        else: # save subset
                            # create map of gaps
                            subset_ds['aso_gap_map'] = np.multiply(np.isnan(subset_ds.aso_sd), 1)
                            
                            # radar gap maps
                            subset_ds['rtc_gap_map'] = np.multiply(((np.isnan(subset_ds.snowon_vv) +
                                                                     np.isnan(subset_ds.snowon_vh) +
                                                                     np.isnan(subset_ds.snowoff_vv) +
                                                                     np.isnan(subset_ds.snowoff_vh)) > 0), 1)
    
                            #subset_ds['rtc_mean_gap_map'] = np.multiply(((np.isnan(subset_ds.snowon_vv_mean) +
                            #                                         np.isnan(subset_ds.snowon_vh_mean) +
                            #                                         np.isnan(subset_ds.snowoff_vv_mean) +
                            #                                         np.isnan(subset_ds.snowoff_vh_mean)) > 0), 1)
    
                            # s2 gap maps
                            subset_ds['s2_gap_map'] = np.multiply(((np.isnan(subset_ds.B02) +
                                                                   np.isnan(subset_ds.B03) +
                                                                   np.isnan(subset_ds.B04) +
                                                                   np.isnan(subset_ds.B08) +
                                                                   np.isnan(subset_ds.B11)) > 0), 1)

                            # add gaps for high probablity cloud cover
                            subset_ds['s2_gap_map'] = xr.where(subset_ds['SCL'] == 9, 1, subset_ds['s2_gap_map'])
                            subset_ds['s2_gap_map'] = xr.where(subset_ds['SCL'] == 0, 1, subset_ds['s2_gap_map'])
                            
                            # fill nans with 0 
                            subset_ds = subset_ds.fillna(0)

                            # add lat and lon variables 
                            x, y = np.meshgrid(subset_ds['x'].values, subset_ds['y'].values)
                            lon, lat = transform(utm_proj, wgs84_proj, x, y)
                            subset_ds['latitude'] = (('y', 'x'), lat)
                            subset_ds['longitude'] = (('y', 'x'), lon)
                            
                            subset_count+=1
                            total_subsets+=1
                            raster_subsets+=1
                            
                            subset_ds.to_netcdf(rf'{home_path}\subsets_v4\{tile_set.split("_")[0]}\{aso_fn}_tile{int(tile[1].id)}_s{subset_count}.nc')
                            # reproject to wgs for heatmaps
                            subset_ds = subset_ds.rio.reproject("EPSG:4326")
                            subset_ds.aso_sd.rio.to_raster(rf'{home_path}\subsets_v4_tif\{tile_set.split("_")[0]}\{aso_fn}_tile{int(tile[1].id)}_s{subset_count}.tif')
                        
            print(f'total subsets from {aso_fn}: {raster_subsets}')
            gc.collect()
# Out:
# working on utm10n file 0
# working on train_utm10n_32km.shp
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_American_20230131_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_American_20230131_clean
# total subsets from ASO_50M_SD_American_20230131_clean: 100
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_American_20230413_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_American_20230131_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230413_for_ASO_50M_SD_American_20230413_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_American_20230428_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_American_20230413_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230428_for_ASO_50M_SD_American_20230428_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_American_20230602_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_American_20230428_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230602_for_ASO_50M_SD_American_20230602_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Feather_20220310_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Feather_20220310_clean
# total subsets from ASO_50M_SD_Feather_20220310_clean: 185
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Feather_20220331_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Feather_20220310_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20220331_for_ASO_50M_SD_Feather_20220331_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Feather_20220429_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Feather_20220429_clean
# total subsets from ASO_50M_SD_Feather_20220429_clean: 185
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Feather_20230206_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Feather_20220429_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230206_for_ASO_50M_SD_Feather_20230206_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Feather_20230409_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Feather_20230409_clean
# total subsets from ASO_50M_SD_Feather_20230409_clean: 185
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Feather_20230428_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Feather_20230409_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230428_for_ASO_50M_SD_Feather_20230428_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Feather_20230618_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Feather_20230618_clean
# total subsets from ASO_50M_SD_Feather_20230618_clean: 188
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_LowerPit_20230212_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Feather_20230618_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230212_for_ASO_50M_SD_LowerPit_20230212_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_LowerPit_20230425_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_LowerPit_20230212_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230425_for_ASO_50M_SD_LowerPit_20230425_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_LowerPit_20230511_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_LowerPit_20230425_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230511_for_ASO_50M_SD_LowerPit_20230511_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_SacramentoMcCloud_20230209_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_LowerPit_20230511_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230209_for_ASO_50M_SD_SacramentoMcCloud_20230209_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_SacramentoMcCloud_20230424_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_SacramentoMcCloud_20230209_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230424_for_ASO_50M_SD_SacramentoMcCloud_20230424_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_SacramentoMcCloud_20230515_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_SacramentoMcCloud_20230424_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230515_for_ASO_50M_SD_SacramentoMcCloud_20230515_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Sprague_20230514_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Sprague_20230514_clean
# total subsets from ASO_50M_SD_Sprague_20230514_clean: 58
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Truckee_20220310_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Truckee_20220310_clean
# total subsets from ASO_50M_SD_Truckee_20220310_clean: 90
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Truckee_20220408_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Truckee_20220310_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20220408_for_ASO_50M_SD_Truckee_20220408_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Truckee_20220514_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Truckee_20220514_clean
# total subsets from ASO_50M_SD_Truckee_20220514_clean: 90
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Truckee_20230409_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Truckee_20220514_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230409_for_ASO_50M_SD_Truckee_20230409_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Truckee_20230511_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Truckee_20230409_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230511_for_ASO_50M_SD_Truckee_20230511_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Truckee_20230608_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Truckee_20230608_clean
# total subsets from ASO_50M_SD_Truckee_20230608_clean: 91
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_USWAOL_20160208_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_USWAOL_20160208_clean
# total subsets from ASO_50M_SD_USWAOL_20160208_clean: 71
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_USWAOL_20160329_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_USWAOL_20160208_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20160329_for_ASO_50M_SD_USWAOL_20160329_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Yuba_20230128_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_USWAOL_20160329_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230128_for_ASO_50M_SD_Yuba_20230128_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Yuba_20230405_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Yuba_20230128_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230405_for_ASO_50M_SD_Yuba_20230405_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Yuba_20230426_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Yuba_20230405_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230426_for_ASO_50M_SD_Yuba_20230426_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Yuba_20230531_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Yuba_20230426_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230531_for_ASO_50M_SD_Yuba_20230531_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Yuba_20230625_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Yuba_20230531_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230625_for_ASO_50M_SD_Yuba_20230625_clean.nc
# working on test_utm10n_32km.shp
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_American_20230131_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_American_20230131_clean
# total subsets from ASO_50M_SD_American_20230131_clean: 0
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_American_20230413_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_American_20230131_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230413_for_ASO_50M_SD_American_20230413_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_American_20230428_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_American_20230413_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230428_for_ASO_50M_SD_American_20230428_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_American_20230602_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_American_20230428_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230602_for_ASO_50M_SD_American_20230602_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Feather_20220310_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Feather_20220310_clean
# total subsets from ASO_50M_SD_Feather_20220310_clean: 26
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Feather_20220331_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Feather_20220310_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20220331_for_ASO_50M_SD_Feather_20220331_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Feather_20220429_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Feather_20220429_clean
# total subsets from ASO_50M_SD_Feather_20220429_clean: 26
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Feather_20230206_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Feather_20220429_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230206_for_ASO_50M_SD_Feather_20230206_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Feather_20230409_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Feather_20230409_clean
# total subsets from ASO_50M_SD_Feather_20230409_clean: 26
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Feather_20230428_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Feather_20230409_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230428_for_ASO_50M_SD_Feather_20230428_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Feather_20230618_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Feather_20230618_clean
# total subsets from ASO_50M_SD_Feather_20230618_clean: 24
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_LowerPit_20230212_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Feather_20230618_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230212_for_ASO_50M_SD_LowerPit_20230212_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_LowerPit_20230425_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_LowerPit_20230212_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230425_for_ASO_50M_SD_LowerPit_20230425_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_LowerPit_20230511_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_LowerPit_20230425_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230511_for_ASO_50M_SD_LowerPit_20230511_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_SacramentoMcCloud_20230209_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_LowerPit_20230511_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230209_for_ASO_50M_SD_SacramentoMcCloud_20230209_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_SacramentoMcCloud_20230424_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_SacramentoMcCloud_20230209_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230424_for_ASO_50M_SD_SacramentoMcCloud_20230424_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_SacramentoMcCloud_20230515_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_SacramentoMcCloud_20230424_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230515_for_ASO_50M_SD_SacramentoMcCloud_20230515_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Sprague_20230514_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Sprague_20230514_clean
# total subsets from ASO_50M_SD_Sprague_20230514_clean: 0
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Truckee_20220310_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Truckee_20220310_clean
# total subsets from ASO_50M_SD_Truckee_20220310_clean: 0
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Truckee_20220408_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Truckee_20220310_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20220408_for_ASO_50M_SD_Truckee_20220408_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Truckee_20220514_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Truckee_20220514_clean
# total subsets from ASO_50M_SD_Truckee_20220514_clean: 0
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Truckee_20230409_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Truckee_20220514_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230409_for_ASO_50M_SD_Truckee_20230409_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Truckee_20230511_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Truckee_20230409_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230511_for_ASO_50M_SD_Truckee_20230511_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Truckee_20230608_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Truckee_20230608_clean
# total subsets from ASO_50M_SD_Truckee_20230608_clean: 0
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_USWAOL_20160208_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_USWAOL_20160208_clean
# total subsets from ASO_50M_SD_USWAOL_20160208_clean: 9
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_USWAOL_20160329_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_USWAOL_20160208_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20160329_for_ASO_50M_SD_USWAOL_20160329_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Yuba_20230128_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_USWAOL_20160329_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230128_for_ASO_50M_SD_Yuba_20230128_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Yuba_20230405_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Yuba_20230128_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230405_for_ASO_50M_SD_Yuba_20230405_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Yuba_20230426_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Yuba_20230405_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230426_for_ASO_50M_SD_Yuba_20230426_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Yuba_20230531_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Yuba_20230426_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230531_for_ASO_50M_SD_Yuba_20230531_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Yuba_20230625_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Yuba_20230531_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230625_for_ASO_50M_SD_Yuba_20230625_clean.nc
# working on val_utm10n_32km.shp
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_American_20230131_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_American_20230131_clean
# total subsets from ASO_50M_SD_American_20230131_clean: 10
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_American_20230413_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_American_20230131_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230413_for_ASO_50M_SD_American_20230413_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_American_20230428_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_American_20230413_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230428_for_ASO_50M_SD_American_20230428_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_American_20230602_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_American_20230428_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230602_for_ASO_50M_SD_American_20230602_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Feather_20220310_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Feather_20220310_clean
# total subsets from ASO_50M_SD_Feather_20220310_clean: 38
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Feather_20220331_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Feather_20220310_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20220331_for_ASO_50M_SD_Feather_20220331_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Feather_20220429_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Feather_20220429_clean
# total subsets from ASO_50M_SD_Feather_20220429_clean: 38
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Feather_20230206_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Feather_20220429_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230206_for_ASO_50M_SD_Feather_20230206_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Feather_20230409_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Feather_20230409_clean
# total subsets from ASO_50M_SD_Feather_20230409_clean: 38
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Feather_20230428_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Feather_20230409_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230428_for_ASO_50M_SD_Feather_20230428_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Feather_20230618_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Feather_20230618_clean
# total subsets from ASO_50M_SD_Feather_20230618_clean: 38
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_LowerPit_20230212_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Feather_20230618_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230212_for_ASO_50M_SD_LowerPit_20230212_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_LowerPit_20230425_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_LowerPit_20230212_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230425_for_ASO_50M_SD_LowerPit_20230425_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_LowerPit_20230511_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_LowerPit_20230425_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230511_for_ASO_50M_SD_LowerPit_20230511_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_SacramentoMcCloud_20230209_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_LowerPit_20230511_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230209_for_ASO_50M_SD_SacramentoMcCloud_20230209_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_SacramentoMcCloud_20230424_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_SacramentoMcCloud_20230209_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230424_for_ASO_50M_SD_SacramentoMcCloud_20230424_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_SacramentoMcCloud_20230515_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_SacramentoMcCloud_20230424_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230515_for_ASO_50M_SD_SacramentoMcCloud_20230515_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Sprague_20230514_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Sprague_20230514_clean
# total subsets from ASO_50M_SD_Sprague_20230514_clean: 0
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Truckee_20220310_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Truckee_20220310_clean
# total subsets from ASO_50M_SD_Truckee_20220310_clean: 5
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Truckee_20220408_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Truckee_20220310_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20220408_for_ASO_50M_SD_Truckee_20220408_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Truckee_20220514_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Truckee_20220514_clean
# total subsets from ASO_50M_SD_Truckee_20220514_clean: 5
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Truckee_20230409_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Truckee_20220514_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230409_for_ASO_50M_SD_Truckee_20230409_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Truckee_20230511_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Truckee_20230409_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230511_for_ASO_50M_SD_Truckee_20230511_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Truckee_20230608_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Truckee_20230608_clean
# total subsets from ASO_50M_SD_Truckee_20230608_clean: 5
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_USWAOL_20160208_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_USWAOL_20160208_clean
# total subsets from ASO_50M_SD_USWAOL_20160208_clean: 0
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_USWAOL_20160329_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_USWAOL_20160208_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20160329_for_ASO_50M_SD_USWAOL_20160329_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Yuba_20230128_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_USWAOL_20160329_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230128_for_ASO_50M_SD_Yuba_20230128_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Yuba_20230405_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Yuba_20230128_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230405_for_ASO_50M_SD_Yuba_20230405_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Yuba_20230426_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Yuba_20230405_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230426_for_ASO_50M_SD_Yuba_20230426_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Yuba_20230531_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Yuba_20230426_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230531_for_ASO_50M_SD_Yuba_20230531_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm10n\ASO_50M_SD_Yuba_20230625_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Yuba_20230531_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230625_for_ASO_50M_SD_Yuba_20230625_clean.nc
# working on utm11n file 1
# working on train_utm11n_32km.shp
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Carson_20220311_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Yuba_20230625_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20220311_for_ASO_50M_SD_Carson_20220311_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Carson_20220406_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Carson_20220406_clean
# total subsets from ASO_50M_SD_Carson_20220406_clean: 56
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Carson_20220513_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Carson_20220406_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20220513_for_ASO_50M_SD_Carson_20220513_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Carson_20230331_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Carson_20220513_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230331_for_ASO_50M_SD_Carson_20230331_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Carson_20230510_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Carson_20230331_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230510_for_ASO_50M_SD_Carson_20230510_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Carson_20230607_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Carson_20230510_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230607_for_ASO_50M_SD_Carson_20230607_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kaweah_20210423_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Kaweah_20210423_clean
# total subsets from ASO_50M_SD_Kaweah_20210423_clean: 30
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kaweah_20210504_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Kaweah_20210423_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20210504_for_ASO_50M_SD_Kaweah_20210504_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kaweah_20220308_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Kaweah_20210504_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20220308_for_ASO_50M_SD_Kaweah_20220308_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kaweah_20220327_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Kaweah_20220327_clean
# total subsets from ASO_50M_SD_Kaweah_20220327_clean: 30
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kaweah_20220429_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Kaweah_20220327_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20220429_for_ASO_50M_SD_Kaweah_20220429_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kaweah_20220517_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Kaweah_20220429_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20220517_for_ASO_50M_SD_Kaweah_20220517_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kaweah_20230127_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Kaweah_20220517_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230127_for_ASO_50M_SD_Kaweah_20230127_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kaweah_20230307_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Kaweah_20230307_clean
# total subsets from ASO_50M_SD_Kaweah_20230307_clean: 28
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kaweah_20230405_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Kaweah_20230307_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230405_for_ASO_50M_SD_Kaweah_20230405_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kaweah_20230423_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Kaweah_20230405_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230423_for_ASO_50M_SD_Kaweah_20230423_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kaweah_20230602_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Kaweah_20230602_clean
# total subsets from ASO_50M_SD_Kaweah_20230602_clean: 30
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kern_20230204_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Kaweah_20230602_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230204_for_ASO_50M_SD_Kern_20230204_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kern_20230326_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Kern_20230204_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230326_for_ASO_50M_SD_Kern_20230326_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kern_20230429_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Kern_20230326_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230429_for_ASO_50M_SD_Kern_20230429_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kern_20230603_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Kern_20230429_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230603_for_ASO_50M_SD_Kern_20230603_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kings_20230122_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Kern_20230603_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230122_for_ASO_50M_SD_Kings_20230122_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kings_20230316_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Kings_20230122_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230316_for_ASO_50M_SD_Kings_20230316_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kings_20230331_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Kings_20230316_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230331_for_ASO_50M_SD_Kings_20230331_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kings_20230421_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Kings_20230421_clean
# total subsets from ASO_50M_SD_Kings_20230421_clean: 82
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kings_20230528_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Kings_20230421_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230528_for_ASO_50M_SD_Kings_20230528_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Kings_20230630_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Kings_20230630_clean
# total subsets from ASO_50M_SD_Kings_20230630_clean: 96
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20200413_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Kings_20230630_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20200413_for_ASO_50M_SD_Merced_20200413_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20200507_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Merced_20200413_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20200507_for_ASO_50M_SD_Merced_20200507_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20200521_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Merced_20200521_clean
# total subsets from ASO_50M_SD_Merced_20200521_clean: 31
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20200604_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Merced_20200521_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20200604_for_ASO_50M_SD_Merced_20200604_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20210429_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Merced_20200604_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20210429_for_ASO_50M_SD_Merced_20210429_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20210526_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Merced_20210526_clean
# total subsets from ASO_50M_SD_Merced_20210526_clean: 56
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20220301_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Merced_20210526_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20220301_for_ASO_50M_SD_Merced_20220301_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20220412_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Merced_20220301_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20220412_for_ASO_50M_SD_Merced_20220412_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20220428_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Merced_20220412_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20220428_for_ASO_50M_SD_Merced_20220428_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20220513_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Merced_20220428_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20220513_for_ASO_50M_SD_Merced_20220513_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20230131_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Merced_20230131_clean
# total subsets from ASO_50M_SD_Merced_20230131_clean: 57
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20230303_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Merced_20230131_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230303_for_ASO_50M_SD_Merced_20230303_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20230326_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Merced_20230303_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230326_for_ASO_50M_SD_Merced_20230326_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20230515_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Merced_20230326_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230515_for_ASO_50M_SD_Merced_20230515_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Merced_20230608_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Merced_20230515_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230608_for_ASO_50M_SD_Merced_20230608_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Mono_20230527_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Merced_20230608_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230527_for_ASO_50M_SD_Mono_20230527_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Mono_20230615_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Mono_20230615_clean
# total subsets from ASO_50M_SD_Mono_20230615_clean: 15
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_Mono_20230702_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Mono_20230615_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230702_for_ASO_50M_SD_Mono_20230702_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_SanJoaquin_20200523_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Mono_20230702_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20200523_for_ASO_50M_SD_SanJoaquin_20200523_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm11n\ASO_50M_SD_SanJoaquin_20200608_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# ...
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230416_for_ASO_50M_SD_BlueRiver_20230416_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_BlueRiver_20230529_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_BlueRiver_20230416_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230529_for_ASO_50M_SD_BlueRiver_20230529_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_Blue_20220419_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_BlueRiver_20230529_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20220419_for_ASO_50M_SD_Blue_20220419_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_Blue_20220526_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Blue_20220526_clean
# total subsets from ASO_50M_SD_Blue_20220526_clean: 3
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_BoulderCreek_20230509_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Blue_20220526_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230509_for_ASO_50M_SD_BoulderCreek_20230509_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_ClearCreek_20230509_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_BoulderCreek_20230509_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230509_for_ASO_50M_SD_ClearCreek_20230509_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_Conejos_20210420_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_ClearCreek_20230509_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20210420_for_ASO_50M_SD_Conejos_20210420_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_Conejos_20210516_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Conejos_20210516_clean
# total subsets from ASO_50M_SD_Conejos_20210516_clean: 0
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_Conejos_20220415_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Conejos_20210516_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20220415_for_ASO_50M_SD_Conejos_20220415_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_Conejos_20220510_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Conejos_20220415_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20220510_for_ASO_50M_SD_Conejos_20220510_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_Conejos_20230505_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Conejos_20220510_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230505_for_ASO_50M_SD_Conejos_20230505_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_EastRiver_20220518_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Conejos_20230505_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20220518_for_ASO_50M_SD_EastRiver_20220518_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_EastRiver_20230401_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_EastRiver_20230401_clean
# total subsets from ASO_50M_SD_EastRiver_20230401_clean: 0
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_EastRiver_20230523_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_EastRiver_20230401_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230523_for_ASO_50M_SD_EastRiver_20230523_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_GunnisonTaylor_20220421_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_GunnisonTaylor_20220421_clean
# total subsets from ASO_50M_SD_GunnisonTaylor_20220421_clean: 9
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_GunnisonTaylor_20220525_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_GunnisonTaylor_20220421_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20220525_for_ASO_50M_SD_GunnisonTaylor_20220525_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_Gunnison_20220421_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Gunnison_20220421_clean
# total subsets from ASO_50M_SD_Gunnison_20220421_clean: 10
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_Poudre_20230522_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Gunnison_20220421_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230522_for_ASO_50M_SD_Poudre_20230522_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_RoaringFork_20230411_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_RoaringFork_20230411_clean
# total subsets from ASO_50M_SD_RoaringFork_20230411_clean: 0
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_RoaringFork_20230528_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_RoaringFork_20230411_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230528_for_ASO_50M_SD_RoaringFork_20230528_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_SouthPlatte_20230416_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_RoaringFork_20230528_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230416_for_ASO_50M_SD_SouthPlatte_20230416_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_SouthPlatte_20230526_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_SouthPlatte_20230526_clean
# total subsets from ASO_50M_SD_SouthPlatte_20230526_clean: 32
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_StVrainLefthand_20230521_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_StVrainLefthand_20230521_clean
# total subsets from ASO_50M_SD_StVrainLefthand_20230521_clean: 0
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_TaylorAndLottis_20230523_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_StVrainLefthand_20230521_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230523_for_ASO_50M_SD_TaylorAndLottis_20230523_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_Taylor_20230401_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_Taylor_20230401_clean
# total subsets from ASO_50M_SD_Taylor_20230401_clean: 10
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_TenMileCk_20190613_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_Taylor_20230401_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20190613_for_ASO_50M_SD_TenMileCk_20190613_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_USCOBR_20190419_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_TenMileCk_20190613_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20190419_for_ASO_50M_SD_USCOBR_20190419_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_USCOBR_20190624_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_USCOBR_20190419_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20190624_for_ASO_50M_SD_USCOBR_20190624_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_USCOCB_20180330_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_USCOBR_20190624_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20180330_for_ASO_50M_SD_USCOCB_20180330_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_USCOCJ_20160403_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_USCOCB_20180330_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20160403_for_ASO_50M_SD_USCOCJ_20160403_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_USCOCM_20190407_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_USCOCM_20190407_clean
# total subsets from ASO_50M_SD_USCOCM_20190407_clean: 0
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_USCOCM_20190610_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_USCOCM_20190407_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20190610_for_ASO_50M_SD_USCOCM_20190610_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_USCOCP_20210319_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_USCOCM_20190610_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20210319_for_ASO_50M_SD_USCOCP_20210319_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_USCOFR_20200211_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_USCOFR_20200211_clean
# total subsets from ASO_50M_SD_USCOFR_20200211_clean: 0
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_USCOFR_20210319_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_USCOFR_20200211_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20210319_for_ASO_50M_SD_USCOFR_20210319_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_USCOGE_20180331_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_USCOGE_20180331_clean
# total subsets from ASO_50M_SD_USCOGE_20180331_clean: 0
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_USCOGE_20180524_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_USCOGE_20180331_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20180524_for_ASO_50M_SD_USCOGE_20180524_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_USCOGE_20190407_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_USCOGE_20190407_clean
# total subsets from ASO_50M_SD_USCOGE_20190407_clean: 0
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_USCOGE_20190610_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_USCOGE_20190407_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20190610_for_ASO_50M_SD_USCOGE_20190610_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_USCOGT_20180330_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_USCOGE_20190610_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20180330_for_ASO_50M_SD_USCOGT_20180330_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_USCOGT_20190408_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_USCOGT_20180330_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20190408_for_ASO_50M_SD_USCOGT_20190408_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_USCOGT_20190609_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_USCOGT_20190408_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20190609_for_ASO_50M_SD_USCOGT_20190609_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_USCORG_20160403_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_USCOGT_20190609_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20160403_for_ASO_50M_SD_USCORG_20160403_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_WindyGap_20220418_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_USCORG_20160403_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20220418_for_ASO_50M_SD_WindyGap_20220418_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_WindyGap_20220526_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# working on ASO_50M_SD_WindyGap_20220526_clean
# total subsets from ASO_50M_SD_WindyGap_20220526_clean: 0
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_WindyGap_20230416_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_WindyGap_20220526_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230416_for_ASO_50M_SD_WindyGap_20230416_clean.nc
# C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\ASO_50m_SD_cleaned\utm13n\ASO_50M_SD_WindyGap_20230527_clean.tif C:\Users\JackE\uw\courses\aut24\ml_geo\final_data
# encountered error opening dataset ASO_50M_SD_WindyGap_20230416_clean... missing S2 data, skipping
# no C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\sentinel_2\20230527_for_ASO_50M_SD_WindyGap_20230527_clean.nc

# %%
# final sizes
# each file is a 128x128 pixel raster with 50m resolution
# targets are not labels but continuous values representing snow depth in meters
print(f'Training data file count: {len(glob(r"C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\subsets_v4\train\*.nc"))}')
print(f'Testing data file count: {len(glob(r"C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\subsets_v4\test\*.nc"))}')
print(f'Validation data file count: {len(glob(r"C:\Users\JackE\uw\courses\aut24\ml_geo\final_data\subsets_v4\val\*.nc"))}')
# Out:
# Training data file count: 3366
# Testing data file count: 451
# Validation data file count: 589
